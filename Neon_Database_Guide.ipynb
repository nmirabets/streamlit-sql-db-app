# %% [markdown]
# # 🐘 Neon PostgreSQL Database Guide
#
# Welcome! This hands-on notebook will walk you through the basics of working with a **PostgreSQL** database hosted on [**Neon**](https://neon.tech) — a serverless, fully managed Postgres platform. By the end, you'll know how to connect, create tables, insert data, and run queries like a pro! 💪
#
# ---
#
# ### 📋 What You'll Learn
#
# 1. 🔌 **Connect** to a Neon PostgreSQL database
# 2. 🏗️ **Create** a table using SQL
# 3. ✍️ **Insert** data using SQL
# 4. 🔍 **Query** data and display results
# 5. 📊 **Analyze** the data with aggregations
#
# ---
#
# > ### ⚠️ Before You Start — Set Up Your Neon Database
# >
# > If you don't have a Neon database yet, follow these steps:
# >
# > 1. 🌐 Go to [**https://console.neon.tech**](https://console.neon.tech) and sign up for a free account
# > 2. ➕ Click **"New Project"** to create a new database project
# > 3. 📋 Copy the **connection string** (it looks like `postgresql://user:pass@ep-xxxx.region.aws.neon.tech/neondb`)
# > 4. 📝 Create a `.env` file in this project's root folder and add:
# >    ```
# >    DATABASE_URL=your_connection_string_here
# >    ```
# >
# > ✅ That's it! You're ready to go. The free tier is more than enough for this tutorial.
#
# ---
#
# 🎯 *Perfect for bootcamp students learning SQL and Python!*

# %% [markdown]
# ## 📦 Step 1: Install Required Dependencies
#
# First things first — let's install the Python packages we need. Here's what each one does:
#
# | Package | What It Does |
# |---------|-------------|
# | `sqlalchemy` | 🔗 A Python toolkit that makes it easy to talk to databases |
# | `pandas` | 🐼 The go-to library for working with tabular data |
# | `python-dotenv` | 🔐 Loads sensitive credentials from a `.env` file (so we don't hardcode passwords!) |
# | `psycopg2` | 🐘 The PostgreSQL adapter that lets Python communicate with Postgres |
#
# 👇 Run the cell below to install them:

# %%
# %pip install sqlalchemy pandas python-dotenv psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 📚 Step 2: Import Libraries & Load Credentials
#
# Now let's import the libraries and load our database credentials from the `.env` file.
#
# 🔐 **Why use a `.env` file?** It keeps your database password out of your code — this is a security best practice you should always follow!
#
# 👇 Run the cell below to set everything up:

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE_URL = os.getenv('DATABASE_URL').replace('postgresql://', 'postgresql+psycopg://', 1)
DATABASE_URL
# Out:
# 'postgresql+psycopg://neondb_owner:npg_yhc1KZJ6vATa@ep-rapid-grass-agmca99n-pooler.c-2.eu-central-1.aws.neon.tech/neondb?sslmode=require'

# %% [markdown]
# ## 🔌 Step 3: Connect to the Database
#
# Time to connect to our Neon PostgreSQL database! 🎉
#
# **SQLAlchemy** acts as a bridge between Python and our database. We create an `engine` object — think of it as opening a phone line to our database that we can use whenever we need to talk to it.
#
# > 💡 **Tip:** If the connection fails, double-check that your `DATABASE_URL` in the `.env` file is correct. You can find it in your [Neon Dashboard](https://console.neon.tech).
#
# 👇 Let's connect:

# %%
# Create a connection to our database
engine = create_engine(DATABASE_URL)

# Test if our connection works
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT version()"))
        version = result.fetchone()[0]
        print(f"✅ Connected successfully!")
        print(f"Database version: {version}")  # Show first 50 characters
except Exception as e:
    print(f"❌ Connection failed: {e}")
    print("Make sure your DATABASE_URL is correct!")
# Out:
# ✅ Connected successfully!
# Database version: PostgreSQL 17.8 (a284a84) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit

# %% [markdown]
# ## 🏗️ Step 4: Create a Table
#
# Now for the fun part — let's create our first table! 🎉
#
# A **table** is like a spreadsheet in your database. We define its **columns** (the fields) and what **type** of data each column holds. Here's what our `employees` table will look like:
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `id` | SERIAL | 🔢 Auto-incrementing unique ID |
# | `name` | VARCHAR(100) | 👤 Employee's full name |
# | `email` | VARCHAR(100) | 📧 Unique email address |
# | `department` | VARCHAR(50) | 🏢 Department they work in |
# | `salary` | DECIMAL | 💰 Annual salary |
# | `hire_date` | DATE | 📅 When they were hired |
# | `created_at` | TIMESTAMP | 🕐 When the record was created |
#
# > 💡 **Note:** `CREATE TABLE IF NOT EXISTS` means it won't error out if the table already exists — handy for re-running this notebook!
#
# 👇 Let's create it:

# %%
# SQL command to create our employees table
create_table_sql = """
CREATE TABLE IF NOT EXISTS employees (
    id SERIAL PRIMARY KEY,
    name VARCHAR(100) NOT NULL,
    email VARCHAR(100) UNIQUE NOT NULL,
    department VARCHAR(50),
    salary DECIMAL(10, 2),
    hire_date DATE,
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);
"""

# Execute the SQL command
try:
    with engine.connect() as connection:
        connection.execute(text(create_table_sql))
        connection.commit()
    print("✅ Table 'employees' created successfully!")
except Exception as e:
    print(f"❌ Error creating table: {e}")
# Out:
# ✅ Table 'employees' created successfully!

# %% [markdown]
# ## ✍️ Step 5: Insert Sample Data
#
# An empty table isn't very useful, so let's populate it with some sample employees! 👥
#
# We'll use the SQL `INSERT INTO` statement to add 7 employees across different departments. The code below first checks if data already exists (so we don't accidentally create duplicates when re-running the notebook).
#
# > 💡 **Good Practice:** Always check for existing data before inserting — this prevents duplicate records!
#
# 👇 Let's add our employees:

# %%
# First, let's check if we already have data
check_data_sql = "SELECT COUNT(*) FROM employees;"

with engine.connect() as connection:
    result = connection.execute(text(check_data_sql))
    count = result.fetchone()[0]
    
if count > 0:
    print(f"📊 Table already has {count} employees")
else:
    # SQL to insert sample data
    insert_data_sql = """
    INSERT INTO employees (name, email, department, salary, hire_date) VALUES
    ('Alice Johnson', 'alice.johnson@company.com', 'Engineering', 75000.00, '2023-01-15'),
    ('Bob Smith', 'bob.smith@company.com', 'Marketing', 65000.00, '2023-02-20'),
    ('Carol Williams', 'carol.williams@company.com', 'Engineering', 82000.00, '2023-01-10'),
    ('David Brown', 'david.brown@company.com', 'Sales', 70000.00, '2023-03-05'),
    ('Eva Davis', 'eva.davis@company.com', 'HR', 68000.00, '2023-02-28'),
    ('Frank Miller', 'frank.miller@company.com', 'Engineering', 90000.00, '2022-12-01'),
    ('Grace Wilson', 'grace.wilson@company.com', 'Marketing', 72000.00, '2023-01-25');
    """
    
    # Execute the insert
    try:
        with engine.connect() as connection:
            connection.execute(text(insert_data_sql))
            connection.commit()
        print("✅ Sample data inserted successfully!")
    except Exception as e:
        print(f"❌ Error inserting data: {e}")
# Out:
# ✅ Sample data inserted successfully!

# %% [markdown]
# ## 🔍 Step 6: Query Our Data
#
# This is where the magic happens! ✨ Let's retrieve our data using a `SELECT` statement.
#
# We'll use **pandas** `read_sql_query()` to run our SQL and automatically load the results into a nice, clean DataFrame (a table you can work with in Python).
#
# > 💡 **SQL Tip:** `SELECT *` means "give me all columns". `ORDER BY hire_date DESC` sorts results by hire date, newest first.
#
# 👇 Let's see what's in our database:

# %%
# Simple SQL query to get all employees
query_sql = "SELECT * FROM employees ORDER BY hire_date DESC;"

# Use pandas to run the query and display results nicely
employees_df = pd.read_sql_query(query_sql, engine)

print(f"\n📈 We have {len(employees_df)} employees in our database!")

employees_df
# Out:
# 📈 We have 7 employees in our database!
#    id            name                       email   department   salary  \
# 0   4     David Brown     david.brown@company.com        Sales  70000.0
# 1   5       Eva Davis       eva.davis@company.com           HR  68000.0
# 2   2       Bob Smith       bob.smith@company.com    Marketing  65000.0
# 3   7    Grace Wilson    grace.wilson@company.com    Marketing  72000.0
# 4   1   Alice Johnson   alice.johnson@company.com  Engineering  75000.0
# 5   3  Carol Williams  carol.williams@company.com  Engineering  82000.0
# 6   6    Frank Miller    frank.miller@company.com  Engineering  90000.0
#
#     hire_date                 created_at
# 0  2023-03-05 2026-03-25 08:18:19.482933
# 1  2023-02-28 2026-03-25 08:18:19.482933
# 2  2023-02-20 2026-03-25 08:18:19.482933
# 3  2023-01-25 2026-03-25 08:18:19.482933
# 4  2023-01-15 2026-03-25 08:18:19.482933
# 5  2023-01-10 2026-03-25 08:18:19.482933
# 6  2022-12-01 2026-03-25 08:18:19.482933

# %% [markdown]
# ## 📊 Step 7: Let's Explore Our Data!
#
# Now let's level up our SQL skills! 🚀 We'll write more advanced queries using:
#
# - **`WHERE`** — Filter rows that match a condition (like a search filter 🔎)
# - **`GROUP BY`** — Group rows together to calculate summaries (like a pivot table 📊)
# - **`AVG()`, `COUNT()`, `MAX()`** — Aggregate functions that crunch numbers for us 🧮
#
# 👇 Let's explore:

# %%
# Query 1: Find all Engineering employees
engineering_query = """
SELECT name, salary 
FROM employees 
WHERE department = 'Engineering' 
ORDER BY salary DESC;
"""

engineering_df = pd.read_sql_query(engineering_query, engine)
print("🔧 Engineering Employees:")
display(engineering_df)


# Query 2: Calculate average salary by department
avg_salary_query = """
SELECT 
    department,
    COUNT(*) as employee_count,
    ROUND(AVG(salary), 2) as avg_salary,
    MAX(salary) as highest_salary
FROM employees 
GROUP BY department 
ORDER BY avg_salary DESC;
"""

avg_salary_df = pd.read_sql_query(avg_salary_query, engine)
print("💰 Average Salary by Department:")
display(avg_salary_df)
# Out:
# 🔧 Engineering Employees:
#              name   salary
# 0    Frank Miller  90000.0
# 1  Carol Williams  82000.0
# 2   Alice Johnson  75000.0
# 💰 Average Salary by Department:
#     department  employee_count  avg_salary  highest_salary
# 0  Engineering               3    82333.33         90000.0
# 1        Sales               1    70000.00         70000.0
# 2    Marketing               2    68500.00         72000.0
# 3           HR               1    68000.00         68000.0

# %% [markdown]
# ---
#
# ## 🎉 Congratulations! You've Completed the Database Tutorial!
#
# You just went from zero to querying a real cloud database — that's awesome! 🙌
#
# ---
#
# ### 📝 What You've Learned
#
# **🔌 Database Connection:**
# - ✅ Connected to a cloud PostgreSQL database on **Neon** using SQLAlchemy
# - ✅ Used environment variables (`.env`) to keep credentials safe 🔐
#
# **🏗️ Database Operations:**
# - ✅ Created a table using `CREATE TABLE`
# - ✅ Inserted data using `INSERT INTO`
# - ✅ Queried data using `SELECT`
# - ✅ Filtered data using `WHERE` clauses
# - ✅ Aggregated data using `GROUP BY`, `AVG()`, `COUNT()`, and `MAX()`
#
# **💡 SQL Commands Cheat Sheet:**
#
# | Command | What It Does | Example |
# |---------|-------------|---------|
# | `CREATE TABLE` | 🏗️ Make a new table | `CREATE TABLE users (...)` |
# | `INSERT INTO` | ✍️ Add new rows | `INSERT INTO users VALUES (...)` |
# | `SELECT` | 🔍 Read data | `SELECT * FROM users` |
# | `WHERE` | 🔎 Filter rows | `WHERE age > 25` |
# | `GROUP BY` | 📊 Summarize data | `GROUP BY department` |
# | `ORDER BY` | 📈 Sort results | `ORDER BY salary DESC` |
#
# ---
#
# ### 🚀 Next Steps for Your Learning Journey
#
# 1. 🧪 **Practice More SQL** — Try writing your own queries on this dataset!
# 2. 🌐 **Build a Web App** — Run the Streamlit app (`streamlit_app.py`) to see a full application
# 3. 🤝 **Learn JOINs** — Combine data from multiple tables
# 4. 📐 **Database Design** — Learn about normalization and relationships
# 5. 📖 **Explore Neon Docs** — Check out [neon.tech/docs](https://neon.tech/docs) for advanced features like branching and autoscaling
#
# ---
#
# ### 🎯 Real-World Applications
#
# These skills power real products that millions of people use every day:
#
# - 🌐 Building web applications with user data
# - 📊 Creating data dashboards for businesses
# - 🛒 Managing e-commerce inventory systems
# - 📱 Building social media platforms
# - 🏥 Healthcare records management
#
# ---
#
# **Great job completing this tutorial! You now have the fundamentals to work with databases in Python! 🐍✨**
#
# *Happy querying!* 🚀

# %%
def test_connection(engine):
    try:
        with engine.connect() as connection:
            result = connection.execute(text("SELECT version()"))
            version = result.fetchone()[0]
            print(f"✅ Connected to database successfully!")
            print(f"Database version: {version}")  # Show first 50 characters
            return True
    except Exception as e:
        print(f"❌ Database connection failed: {e}")
        print("Make sure your DATABASE_URL is correct!")
        return False

# %%
def run_query(engine, query):
    try:
        with engine.connect() as connection:
            connection.execute(text(query))
            connection.commit()
        print(f"✅ Query run successfully!")
    except Exception as e:
        print(f"❌ Error running query: {e}")

# %%
DATABASE_SCHEMA = [
    """
    CREATE TABLE IF NOT EXISTS employees (
        id SERIAL PRIMARY KEY,
        name VARCHAR(100) NOT NULL,
        email VARCHAR(100) UNIQUE NOT NULL,
        department VARCHAR(50),
        salary DECIMAL(10, 2),
        hire_date DATE,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP);
    """,
]

# %%
def initialize_database(DATABASE_SCHEMA):
    # 1. Open connection with database
    engine = create_engine(DATABASE_URL)
    # 2. Test Connection
    if test_connection(engine):
        # 3. Create schema if it doesn't exist
        for query in DATABASE_SCHEMA:
            # Execute the SQL command
            run_query(engine, query)
    return engine

engine = initialize_database(DATABASE_SCHEMA)
# Out:
# ✅ Connected to database successfully!
# Database version: PostgreSQL 17.8 (a284a84) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14+deb12u1) 12.2.0, 64-bit
# ✅ Query run successfully!
